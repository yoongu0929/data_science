# %%
import re

wine_raw_data = pd.read_csv("title_without_winery.csv")

# 필요없는 컬럼 삭제
wine_raw_data.drop(columns=['Unnamed: 0','taster_twitter_handle'] , axis=1, inplace=True)

# price랑 country Nan 데이타 제거
wine_raw_data.dropna(subset=['price', 'country'], inplace = True)
wine_raw_data.head(5)
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
#
#                                                title             variety  \
# 1                          2011 Avidagos Red (Douro)      Portuguese Red
# 2                2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3   2013 Reserve Late Harvest Riesling (Lake Mich...            Riesling
# 4   2012 Vintner's Reserve Wild Child Block Pinot...          Pinot Noir
# 5     2011 Ars In Vitro Tempranillo-Merlot (Navarra)  Tempranillo-Merlot
#
#                 winery
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks
# 5               Tandem

# %%
def get_year(data):
    years = re.findall("\d+", data)
    if len(years) > 0:
        year = sorted([int(year) for year in years], reverse=True)[0]
        return year if year <= 2017 and year >= 1998 else 0
    else:
        return 0
    
wine_raw_data["year"] = wine_raw_data["title"].apply(lambda data: get_year(data))

# year 가 0인 데이터 row삭제
wine_raw_data = wine_raw_data[wine_raw_data.year != 0]
wine_raw_data.head(5)
# Out:
#     country                                        description  \
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
# 5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 1                            Avidagos      87   15.0           Douro
# 2                                 NaN      87   14.0          Oregon
# 3                Reserve Late Harvest      87   13.0        Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 5                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
# 5              Navarra                NaN   Michael Schachner
#
#                                                title             variety  \
# 1                          2011 Avidagos Red (Douro)      Portuguese Red
# 2                2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3   2013 Reserve Late Harvest Riesling (Lake Mich...            Riesling
# 4   2012 Vintner's Reserve Wild Child Block Pinot...          Pinot Noir
# 5     2011 Ars In Vitro Tempranillo-Merlot (Navarra)  Tempranillo-Merlot
#
#                 winery  year
# 1  Quinta dos Avidagos  2011
# 2            Rainstorm  2013
# 3           St. Julian  2013
# 4         Sweet Cheeks  2012
# 5               Tandem  2011

# %%
wine_raw_data.groupby("year").size()
# Out:
# year
# 1998      541
# 1999      619
# 2000      735
# 2001      667
# 2002      333
# 2003      499
# 2004     1603
# 2005     3290
# 2006     5168
# 2007     6495
# 2008     6723
# 2009     9054
# 2010    11100
# 2011    11427
# 2012    14722
# 2013    15181
# 2014    14869
# 2015     9619
# 2016     3543
# 2017       11
# dtype: int64

# %%
df = df[df.line_race != 0]
