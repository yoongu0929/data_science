# %% [markdown]
# # 위도/경도

# %%
def make_name01(row):
    if row['region_1'] is np.nan:
        return ", ".join([row['country'], row['province']])
    return ", ".join(set([row['country'], row['province'], row['region_1']]))
    
unique_places["name1"] = unique_places.apply(lambda row: make_name01(row), axis=1)

# %%
def make_name02(row):
    if row['province'] is np.nan:
        return row['country']
    return ", ".join([row['country'], row['province']])
    
unique_places["name2"] = unique_places.apply(lambda row: make_name02(row), axis=1)

# %%
def make_name03(row):
        return row['country']
    
unique_places["name3"] = unique_places.apply(lambda row: make_name03(row), axis=1)

# %%
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter
# import time
# import numpy as np
# from tqdm import tqdm

# tqdm.pandas()

# geolocator = Nominatim(user_agent="wine_rating")
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# unique_places['location1'] = unique_places["name1"].progress_apply(geocode)


# unique_places['latitude1'] = unique_places['location1'].apply(lambda loc: loc.point.latitude if loc else None)
# unique_places['longitude1'] = unique_places['location1'].apply(lambda loc: loc.point.longitude if loc else None)


# # df_places.to_csv("latitude_longitude_v4.csv", mode="w")

# %%
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter
# import time
# import numpy as np
# from tqdm import tqdm

# tqdm.pandas()

# geolocator = Nominatim(user_agent="wine_rating")
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# unique_places['location2'] = unique_places["name2"].progress_apply(geocode)


# unique_places['latitude2'] = unique_places['location2'].apply(lambda loc: loc.point.latitude if loc else None)
# unique_places['longitude2'] = unique_places['location2'].apply(lambda loc: loc.point.longitude if loc else None)

# %%
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter
# import time
# import numpy as np
# from tqdm import tqdm

# tqdm.pandas()

# geolocator = Nominatim(user_agent="wine_rating")
# geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)
# unique_places['location3'] = unique_places["name3"].progress_apply(geocode)


# unique_places['latitude3'] = unique_places['location3'].apply(lambda loc: loc.point.latitude if loc else None)
# unique_places['longitude3'] = unique_places['location3'].apply(lambda loc: loc.point.longitude if loc else None)

# %%
lat_lng.location1 = lat_lng.location1.fillna(value=lat_lng.location2)
lat_lng.latitude1 = lat_lng.latitude1.fillna(value=lat_lng.latitude2)
lat_lng.longitude1 = lat_lng.longitude1.fillna(value=lat_lng.longitude2)

# %%
lat_lng.location1 = lat_lng.location1.fillna(value=lat_lng.location3)
lat_lng.latitude1 = lat_lng.latitude1.fillna(value=lat_lng.latitude3)
lat_lng.longitude1 = lat_lng.longitude1.fillna(value=lat_lng.longitude3)
lat_lng

# %%
lat_lng.loc[lat_lng.location1.isnull()]

# %% [markdown]
# # 와인데이터 + 위도경도 merge

# %%
lat_lng = pd.read_csv("latitude_longitude_final_190610.csv")
lat_lng.drop(columns=['Unnamed: 0'] , axis=1, inplace=True)
lat_lng
# Out:
#            country                    province               region_1  \
# 0         Portugal                       Douro                    NaN
# 1               US                      Oregon      Willamette Valley
# 2               US                    Michigan    Lake Michigan Shore
# 3            Spain              Northern Spain                Navarra
# 4            Italy           Sicily & Sardinia               Vittoria
# 5           France                      Alsace                 Alsace
# 6          Germany                 Rheinhessen                    NaN
# 7               US                  California            Napa Valley
# 8               US                  California       Alexander Valley
# 9               US                  California          Central Coast
# 10         Germany                       Mosel                    NaN
# 11       Argentina                       Other               Cafayate
# ...

# %%
lat_lng.loc[lat_lng.latitude.isnull()]
# Out:
# Empty DataFrame
# Columns: [country, province, region_1, name, location, latitude, longitude]
# Index: []

# %%
# 116199개
wine_data_js = pd.read_csv("wine_raw_data_js.csv")
wine_data_js
# Out:
#         Unnamed: 0      country  \
# 0                1     Portugal
# 1                2           US
# 2                3           US
# 3                4           US
# 4                5        Spain
# 5                6        Italy
# 6                7       France
# 7                8      Germany
# 8                9       France
# 9               10           US
# 10              11       France
# 11              12           US
# 12              14           US
# 13              15      Germany
# 14              16    Argentina
# 15              17    Argentina
# 16              18        Spain
# 17              19           US
# 18              20           US
# 19              21           US
# 20              22        Italy
# 21              23           US
# 22              24        Italy
# 23              25           US
# 24              26        Italy
# 25              27        Italy
# 26              28        Italy
# 27              29           US
# ...

# %%
def make_name(row):
    if row['region_1'] is np.nan:
        return ", ".join([row['country'], row['province']])
    return ", ".join(set([row['country'], row['province'], row['region_1']]))
    
wine_data_js["name"] = wine_data_js.apply(lambda row: make_name(row), axis=1)

# %%
wine_data_js
# Out:
#         Unnamed: 0      country  \
# 0                1     Portugal
# 1                2           US
# 2                3           US
# 3                4           US
# 4                5        Spain
# 5                6        Italy
# 6                7       France
# 7                8      Germany
# 8                9       France
# 9               10           US
# 10              11       France
# 11              12           US
# 12              14           US
# 13              15      Germany
# 14              16    Argentina
# 15              17    Argentina
# 16              18        Spain
# 17              19           US
# 18              20           US
# 19              21           US
# 20              22        Italy
# 21              23           US
# 22              24        Italy
# 23              25           US
# 24              26        Italy
# 25              27        Italy
# 26              28        Italy
# 27              29           US
# ...

# %%
# 와인데이터 + 위도경도 merge
winte_data_lat_lng_merge = pd.merge(wine_data_js, lat_lng, how='left', on=['country', 'province', 'region_1'])
winte_data_lat_lng_merge
# Out:
#         Unnamed: 0      country  \
# 0                1     Portugal
# 1                2           US
# 2                3           US
# 3                4           US
# 4                5        Spain
# 5                6        Italy
# 6                7       France
# 7                8      Germany
# 8                9       France
# 9               10           US
# 10              11       France
# 11              12           US
# 12              14           US
# 13              15      Germany
# 14              16    Argentina
# 15              17    Argentina
# 16              18        Spain
# 17              19           US
# 18              20           US
# 19              21           US
# 20              22        Italy
# 21              23           US
# 22              24        Italy
# 23              25           US
# 24              26        Italy
# 25              27        Italy
# 26              28        Italy
# 27              29           US
# ...

# %%
# 와인데이터 + 위도경도 merge 후 컬럼 정리
winte_data_lat_lng_merge.drop(columns=['Unnamed: 0', 'name_x', 'name_y', 'location'] , axis=1, inplace=True)
winte_data_lat_lng_merge
# Out:
#             country                                        description  \
# 0          Portugal  This is ripe and fruity, a wine that is smooth...
# 1                US  Tart and snappy, the flavors of lime flesh and...
# 2                US  Pineapple rind, lemon pith and orange blossom ...
# 3                US  Much like the regular bottling from 2012, this...
# 4             Spain  Blackberry and raspberry aromas show a typical...
# 5             Italy  Here's a bright, informal red that opens with ...
# 6            France  This dry and restrained wine offers spice in p...
# 7           Germany  Savory dried thyme notes accent sunnier flavor...
# 8            France  This has great depth of flavor with its fresh ...
# 9                US  Soft, supple plum envelopes an oaky structure ...
# 10           France  This is a dry wine, very spicy, with a tight, ...
# 11               US  Slightly reduced, this wine offers a chalky, t...
# ...

# %%
# csv 파일로 저장
winte_data_lat_lng_merge.to_csv("winte_data_lat_lng_merge.csv", mode="w")
