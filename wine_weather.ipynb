# %%
we = pd.read_csv("final_rain_temp_1991-2016.csv")
# Out:
#       Unnamed: 0   latitude   longitude               1월강수량  \
# 0              0  41.170042   -7.304750  108.27307891845703
# 1              1  45.344287 -122.667037    154.484619140625
# 2              2  45.365872  -85.114064   51.30384826660156
# 3              3  39.326234   -4.838065  43.907691955566406
# 4              4  42.638426   12.674297  59.873077392578125
# 5              5  48.249176    7.407470   61.78461456298828
# 6              6  49.904518    8.271108   42.46154022216797
# 7              7  39.023468  -84.450465                78.0
# 8              8  39.065206  -84.427239                78.0
# 9              9  36.701463 -118.755997  131.83462524414062
# 10            10  50.365975    7.585825   57.33076858520508
# 11            11 -34.716524  -58.275414  108.31538391113281
# 12            12 -32.889729  -68.844296  45.126922607421875
# 13            13  39.326234   -4.838065  43.907691955566406
# 14            14  37.123224  -78.492772   89.53845977783203
# ...

# %%
we.drop("Unnamed: 0", axis=1, inplace=True)
we = we.drop_duplicates()

# %%
we
# Out:
#        latitude   longitude               1월강수량               2월강수량  \
# 0     41.170042   -7.304750  108.27307891845703   77.61154174804688
# 1     45.344287 -122.667037    154.484619140625  110.66923522949219
# 2     45.365872  -85.114064   51.30384826660156  35.126922607421875
# 3     39.326234   -4.838065  43.907691955566406  40.615386962890625
# 4     42.638426   12.674297  59.873077392578125  58.657691955566406
# 5     48.249176    7.407470   61.78461456298828  53.588462829589844
# 6     49.904518    8.271108   42.46154022216797  37.869232177734375
# 7     39.023468  -84.450465                78.0  63.003849029541016
# 8     39.065206  -84.427239                78.0  63.003849029541016
# 9     36.701463 -118.755997  131.83462524414062  114.92692565917969
# 10    50.365975    7.585825   57.33076858520508  47.515384674072266
# 11   -34.716524  -58.275414  108.31538391113281  109.53462219238281
# 12   -32.889729  -68.844296  45.126922607421875  38.161537170410156
# ...

# %%
wine_data_lat_lng_merge = pd.read_csv("wine_data_lat_lng_merge")
tude = wine_data_lat_lng_merge[["Unnamed: 0", "country", "points", "price","year", "latitude", "longitude"]]
tude.tail()
# Out:
#         Unnamed: 0  country  points  price  year   latitude   longitude
# 116194      116194  Germany      90   28.0  2013  50.365975    7.585825
# 116195      116195       US      90   75.0  2004  43.979280 -120.737257
# 116196      116196   France      90   30.0  2013  48.249176    7.407470
# 116197      116197   France      90   32.0  2012  48.249176    7.407470
# 116198      116198   France      90   21.0  2012  48.249176    7.407470

# %%
wine_weather = pd.merge( tude, we,  on=["latitude","longitude"], how="left")
wine_weather.tail(10)
# Out:
#         Unnamed: 0   country  points  price  year   latitude   longitude  \
# 116189      116189  Portugal      90   48.0  2006  41.170042   -7.304750
# 116190      116190     Italy      90   30.0  2013  42.638426   12.674297
# 116191      116191     Italy      90   40.0  2012  42.638426   12.674297
# 116192      116192    Israel      90   20.0  2012  32.861663   35.264013
# 116193      116193    France      90   28.0  2013  48.249176    7.407470
# 116194      116194   Germany      90   28.0  2013  50.365975    7.585825
# 116195      116195        US      90   75.0  2004  43.979280 -120.737257
# 116196      116196    France      90   30.0  2013  48.249176    7.407470
# 116197      116197    France      90   32.0  2012  48.249176    7.407470
# 116198      116198    France      90   21.0  2012  48.249176    7.407470
#
#                      1월강수량               2월강수량               3월강수량  \
# 116189  108.27307891845703   77.61154174804688    72.6423110961914
# ...

# %%
wine_weather.to_csv("wine_weather.csv")
